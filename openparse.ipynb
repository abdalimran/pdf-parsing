# %%
import openparse

basic_doc_path = "1-s2.0-S1877050924011402-main.pdf"
parser = openparse.DocumentParser()
parsed_basic_doc = parser.parse(basic_doc_path)

# %%
for node in parsed_basic_doc.nodes:
    print(node)
# Out:
# id_='0c14414e-0ea6-44ef-874e-4c000c74ff0f' elements=(ImageElement(text='', bbox=Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116), image='...', image_mimetype='image/jpeg', variant=<NodeVariant.IMAGE: 'image'>, embed_text=''),) tokenization_lower_limit=256 tokenization_upper_limit=1024 coordinate_system='bottom-left' embedding=None node_id='0c14414e-0ea6-44ef-874e-4c000c74ff0f' variant={'image'} tokens=512 images=[ImageElement(text='', bbox=Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116), image='...', image_mimetype='image/jpeg', variant=<NodeVariant.IMAGE: 'image'>, embed_text='')] bbox=[Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116)] text=''
# ...

# %%
for node in parsed_basic_doc.nodes:
    display(node)
# Out:
# Node(id_='0c14414e-0ea6-44ef-874e-4c000c74ff0f', elements=(ImageElement(text='', bbox=Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116), image='...', image_mimetype='image/jpeg', variant=<NodeVariant.IMAGE: 'image'>, embed_text=''),), tokenization_lower_limit=256, tokenization_upper_limit=1024, coordinate_system='bottom-left', embedding=None, node_id='0c14414e-0ea6-44ef-874e-4c000c74ff0f', variant={'image'}, tokens=512, images=[ImageElement(text='', bbox=Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116), image='...', image_mimetype='image/jpeg', variant=<NodeVariant.IMAGE: 'image'>, embed_text='')], bbox=[Bbox(page=0, page_height=742.677, page_width=544.252, x0=117.4808655, y0=662.2958984, x1=148.9448835, y1=693.6399116)], text='')
# ...
